# %% [markdown]
# <a href="https://colab.research.google.com/github/saranya-45/image-classification/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## explorative data analasis

# %% [markdown]
# ## analasis using car

# %% [markdown]
# the steps involved in this  are important

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('/content/datacar.csv')

# %%
data1
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data1.shape
# Out:
# (11914, 16)

# %%
data1.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
data1.columns.to_list()
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Engine Fuel Type',
#  'Engine HP',
#  'Engine Cylinders',
#  'Transmission Type',
#  'Driven_Wheels',
#  'Number of Doors',
#  'Market Category',
#  'Vehicle Size',
#  'Vehicle Style',
#  'highway MPG',
#  'city mpg',
#  'Popularity',
#  'MSRP']

# %%
data1.rename(columns={'Engine HP':'HP','city mpg':'mpg'},inplace=True)

# %%
data1.columns.to_list()
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Engine Fuel Type',
#  'HP',
#  'Engine Cylinders',
#  'Transmission Type',
#  'Driven_Wheels',
#  'Number of Doors',
#  'Market Category',
#  'Vehicle Size',
#  'Vehicle Style',
#  'highway MPG',
#  'mpg',
#  'Popularity',
#  'MSRP']

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   HP                 11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  mpg                11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
data2=data1.drop(['Market Category','Number of Doors'],axis=1)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   HP                 11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Vehicle Size       11914 non-null  object
#  9   Vehicle Style      11914 non-null  object
#  10  highway MPG        11914 non-null  int64
#  11  mpg                11914 non-null  int64
#  12  Popularity         11914 non-null  int64
#  13  MSRP               11914 non-null  int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.3+ MB

# %%
data2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
data2.duplicated().sum()
# Out:
# np.int64(721)

# %%
data2.drop_duplicates(inplace=True)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11193 entries, 0 to 11913
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11193 non-null  object
#  1   Model              11193 non-null  object
#  2   Year               11193 non-null  int64
#  3   Engine Fuel Type   11190 non-null  object
#  4   HP                 11124 non-null  float64
#  5   Engine Cylinders   11163 non-null  float64
#  6   Transmission Type  11193 non-null  object
#  7   Driven_Wheels      11193 non-null  object
#  8   Vehicle Size       11193 non-null  object
#  9   Vehicle Style      11193 non-null  object
#  10  highway MPG        11193 non-null  int64
#  11  mpg                11193 non-null  int64
#  12  Popularity         11193 non-null  int64
#  13  MSRP               11193 non-null  int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.3+ MB

# %%
data2.isnull()
# Out:
#         Make  Model   Year  Engine Fuel Type     HP  Engine Cylinders  \
# 0      False  False  False             False  False             False
# 1      False  False  False             False  False             False
# 2      False  False  False             False  False             False
# 3      False  False  False             False  False             False
# 4      False  False  False             False  False             False
# ...      ...    ...    ...               ...    ...               ...
# 11909  False  False  False             False  False             False
# 11910  False  False  False             False  False             False
# 11911  False  False  False             False  False             False
# 11912  False  False  False             False  False             False
# 11913  False  False  False             False  False             False
#
#        Transmission Type  Driven_Wheels  Vehicle Size  Vehicle Style  \
# ...

# %%
data2.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# HP                   69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# mpg                   0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
data3=data2.dropna()

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11092 entries, 0 to 11913
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11092 non-null  object
#  1   Model              11092 non-null  object
#  2   Year               11092 non-null  int64
#  3   Engine Fuel Type   11092 non-null  object
#  4   HP                 11092 non-null  float64
#  5   Engine Cylinders   11092 non-null  float64
#  6   Transmission Type  11092 non-null  object
#  7   Driven_Wheels      11092 non-null  object
#  8   Vehicle Size       11092 non-null  object
#  9   Vehicle Style      11092 non-null  object
#  10  highway MPG        11092 non-null  int64
#  11  mpg                11092 non-null  int64
#  12  Popularity         11092 non-null  int64
#  13  MSRP               11092 non-null  int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.3+ MB
